# %%
import pandas as pd
import numpy as np
import time

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By   # 특정 요소 존재 여부 확인
from selenium.webdriver.support.ui import WebDriverWait # 웹 페이지 로딩 완료될 때까지 대기
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys # key event 발생 시킴
from selenium.webdriver.support.select import Select

# Exception
from selenium.common.exceptions import TimeoutException, NoSuchElementException

# %%
path = 'C:/programming/multi_final_project/driver/chromedriver.exe'

# 다음뉴스 -> 브랜드 검색 --> 기간 지정 -->  최신순 --> 출처(하퍼스바자) 까지 선택한 후의 링크 
Url = 'https://search.daum.net/search?w=news&sort=recency&q={}&cluster=n&dc=STC&pg=1&r=1&p={}&rc=1&at=more&sd=20160901000000&ed=20201117235959&period=u&cpname=%ED%95%98%ED%8D%BC%EC%8A%A4%EB%B0%94%EC%9E%90&cp=16tGeOd_Hc_jGqFhjc'

# %%
def short_naming(brand_name):
    if brand_name == '셀린느':
        return "Ce"
    elif brand_name == '샤넬':
        return "Ch"
    elif brand_name == '로랑':
        return "YSL"
    elif brand_name == '디올':
        return "D"
    else:
        return "입력오류"

# %%
SearchWord = ['로랑']
brand_code = short_naming(SearchWord[0])

# %%
magazine = 'Daum_BAZAAR'

# %%
# 리스트 초기화 

titleList = []
linkList = []
dateList = []
categoryList = []
contentList = []
Temp_contentList = []

# %% [markdown]
# ### 크롬 브라우저 제어할 수 있는 객체, 웹브라우저 실행

# %%
driver = webdriver.Chrome(path)     # 크롬 브라우저 제어할 수 있는 객체, 웹브라우저 실행
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="3fdc1c322b8494cabe14d15f6f3f21d9")>

# %% [markdown]
# ### 크롤링 실행

# %%
end_of_page = 7

for page in range(1,end_of_page) :
    driver.get(Url.format(SearchWord[0], page))
    contElements = driver.find_elements_by_css_selector('#newsResultUL > li')
    
    for i, cont in enumerate(contElements):
        
        #제목 가져오기
        title = cont.find_element_by_xpath('//*[@id="newsResultUL"]/li[{}]/div/div/div/a'.format(i+1))
        titleList.append(str(title.text))
        print('제목 : ', title.text)
       
        #날짜 가져오기
        date = cont.find_element_by_css_selector('span.f_nb.date').text[:10]
        dateList.append(date)
        print('날짜 :', date)
        
        #페이지 클릭
        title.click()  
        time.sleep(2)

        # 새 탭으로 이동 
        driver.switch_to_window(driver.window_handles[1])

        link = driver.find_element_by_css_selector('head > meta:nth-child(9)').get_attribute('content')
        linkList.append(link)
        print('link :', link)
        
        
        ## 카테고리 가져오기        
        category =  driver.find_element_by_xpath('//*[@id="contents"]/div/div[1]/div/span').text
        categoryList.append(category)
        print(category)
        
        driver.close()

        # 메인 탭으로 가기 
        driver.switch_to_window(driver.window_handles[0])
        time.sleep(2)
        
        # 게시물 10개 읽으면 다음 페이지로 
        print("완료 : {}페이지, {}번 게시물".format(page, i))
        print('-'*50)
        
        if i == 9:
            break
# Out:
# 제목 :  코로나19에도 불티나게 팔린 메이크업 제품은?
# 날짜 : 2020.10.05
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: use driver.switch_to.window instead
# link : https://www.harpersbazaar.co.kr/article/49180
# BEAUTY
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: DeprecationWarning
# 완료 : 5페이지, 4번 게시물
# --------------------------------------------------
# 제목 :  영원히 변치 않는 패션 ‘잇’ 아이템
# 날짜 : 2018.08.20
# link : https://www.harpersbazaar.co.kr/article/39473
# FASHION
# 완료 : 5페이지, 5번 게시물
# --------------------------------------------------
# 제목 :  생 로랑 룩 스마트하게 연출하기
# 날짜 : 2018.08.20
# link : https://www.harpersbazaar.co.kr/article/39472
# FASHION
# 완료 : 5페이지, 6번 게시물
# --------------------------------------------------
# 제목 :  패션 듀오 아카이브
# 날짜 : 2018.08.13
# link : https://www.harpersbazaar.co.kr/article/39453
# FASHION
# 완료 : 5페이지, 7번 게시물
# --------------------------------------------------
# 제목 :  크리스 무어가 담은 런웨이 최고의 순간!
# 날짜 : 2018.07.16
# link : https://www.harpersbazaar.co.kr/article/39377
# FASHION
# 완료 : 5페이지, 8번 게시물
# --------------------------------------------------
# 제목 :  블랙 파워!
# 날짜 : 2018.07.15
# link : https://www.harpersbazaar.co.kr/article/39372
# FASHION
# 완료 : 5페이지, 9번 게시물
# --------------------------------------------------
# 제목 :  패션으로 떠나는 세계여행
# 날짜 : 2018.07.13
# link : https://www.harpersbazaar.co.kr/article/39366
# FASHION
# 완료 : 6페이지, 0번 게시물
# --------------------------------------------------
# 제목 :  2018 F/W 파리 패션위크에서 생긴일
# 날짜 : 2018.07.01
# link : https://www.harpersbazaar.co.kr/article/39327
# FASHION
# 완료 : 6페이지, 1번 게시물
# --------------------------------------------------
# 제목 :  2018 F/W 런던 패션위크 리포트
# 날짜 : 2018.06.29
# link : https://www.harpersbazaar.co.kr/article/39318
# FASHION
# 완료 : 6페이지, 2번 게시물
# --------------------------------------------------
# 제목 :  여름에만 가능한 뷰티 #립티튜드
# 날짜 : 2018.06.29
# link : https://www.harpersbazaar.co.kr/article/39317
# BEAUTY
# 완료 : 6페이지, 3번 게시물
# --------------------------------------------------
# 제목 :  2018 F/W 뉴욕 패션위크 리포트
# 날짜 : 2018.06.28
# link : https://www.harpersbazaar.co.kr/article/39312
# FASHION
# 완료 : 6페이지, 4번 게시물
# --------------------------------------------------
# 제목 :  예뻐도 너무 예쁜 제니의 옷장
# 날짜 : 2018.06.25
# link : https://www.harpersbazaar.co.kr/article/39305
# ART&CULTURE
# 완료 : 6페이지, 5번 게시물
# --------------------------------------------------

# %% [markdown]
# ### 크롤링 결과 확인

# %%
print('len :', len(titleList))
print(titleList)
# Out:
# len : 56
# ['코로나19에도 불티나게 팔린 메이크업 제품은?', '우리가 몰랐던 프라다에 대하여', '베스트와 쇼츠로 완성된 웨스턴 룩', '지금 가장 주목해야 할 패션 뉴스 NEW&HOT', '퓨전 말고 진짜 외국의 맛을 파는 식당들', '샤넬의 자수와 트위드 등을 만드는 비밀 공간은?', '이 쇼츠엔 이 슈즈!', '바자가 주목한 아트 이슈 BEST8', '부부의 세계 배우들, 화장품 어디꺼?', '이번 시즌 런웨이에서 뽑은 베스트 룩', '스타일링이 어려운 베스트, 이렇게 입어!', '코로나 19가 바꾼 럭셔리 공방의 풍경', "마스크에 
# 44  https://www.harpersbazaar.co.kr/article/39512      FASHION            0
# 45  https://www.harpersbazaar.co.kr/article/39473      FASHION            0
# 46  https://www.harpersbazaar.co.kr/article/39472      FASHION            0
# 47  https://www.harpersbazaar.co.kr/article/39453      FASHION            0
# 48  https://www.harpersbazaar.co.kr/article/39377      FASHION            0
# 49  https://www.harpersbazaar.co.kr/article/39372      FASHION            0
# 50  https://www.harpersbazaar.co.kr/article/39366      FASHION            0
# 51  https://www.harpersbazaar.co.kr/article/39327      FASHION            0
# 52  https://www.harpersbazaar.co.kr/article/39318      FASHION            0
# 53  https://www.harpersbazaar.co.kr/article/39317       BEAUTY            0
# 54  https://www.harpersbazaar.co.kr/article/39312      FASHION            0
# 55  https://www.harpersbazaar.co.kr/article/39305  ART&CULTURE            0
#
#     check why Brand
# 0       0   -   YSL
# 1       0   -   YSL
# 2       0   -   YSL
# 3       0   -   YSL
# 4       0   -   YSL
# 5       0   -   YSL
# 6       0   -   YSL
# 7       0   -   YSL
# 8       0   -   YSL
# 9       0   -   YSL
# 10      0   -   YSL
# 11      0   -   YSL
# 12      0   -   YSL
# 13      0   -   YSL
# 14      0   -   YSL
# 15      0   -   YSL
# 16      0   -   YSL
# 17      0   -   YSL
# 18      0   -   YSL
# 19      0   -   YSL
# 20      0   -   YSL
# 21      0   -   YSL
# 22      0   -   YSL
# 23      0   -   YSL
# 24      0   -   YSL
# 25      0   -   YSL
# 26      0   -   YSL
# 27      0   -   YSL
# 28      0   -   YSL
# 29      0   -   YSL
# 30      0   -   YSL
# 31      0   -   YSL
# 32      0   -   YSL
# 33      0   -   YSL
# 34      0   -   YSL
# 35      0   -   YSL
# 36      0   -   YSL
# 37      0   -   YSL
# 38      0   -   YSL
# 39      0   -   YSL
# 40      0   -   YSL
# 41      0   -   YSL
# 42      0   -   YSL
# 43      0   -   YSL
# 44      0   -   YSL
# 45      0   -   YSL
# 46      0   -   YSL
# 47      0   -   YSL
# 48      0   -   YSL
# 49      0   -   YSL
# 50      0   -   YSL
# 51      0   -   YSL
# 52      0   -   YSL
# 53      0   -   YSL
# 54      0   -   YSL
# 55      0   -   YSL

# %% [markdown]
# ### title_brand 처리 : 제목에 브랜드 이름이 있는가?

# %%
title_brand = []

for i in range(len(df['title'])) :
    if SearchWord[0] in df['title'][i] :
        title_brand.append(1)
    else :
        title_brand.append(0)

# %%
df['title_brand'].value_counts()
# Out:
# 0    56
# Name: title_brand, dtype: int64

# %% [markdown]
# ### BEAUTY 카테고리 : check = 2 부여

# %%
df['category'].value_counts()
# Out:
# FASHION        35
# BEAUTY         14
# LIFESTYLE       4
# ART&CULTURE     3
# Name: category, dtype: int64

# %%
for i in range(len(df)) :
    if df['category'][i] == 'BEAUTY' :
        df['check'][i] = 2
    else :
        continue
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['check'].value_counts()
# Out:
# 0    42
# 2    14
# Name: check, dtype: int64

# %% [markdown]
# ### CSV로 저장

# %%
df.to_csv('./data/{}_{}_df_preprocessed.csv'.format(magazine, brand_code) , mode='w' , sep ='|', encoding='utf-8' , index=False)
print('success')
# Out:
# success
